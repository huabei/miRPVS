# %% [markdown]
# # 此文件用于筛选fpocket的输出结果

# %%
import os
import copy
from utils import statistic_pocket_interaction

# %% [markdown]
# # 函数定义

# %%
def is_dibind(file, base=0) -> bool:
    # 用于判断pocket文件中是否同时有蛋白质残基和RNA残基
    # return bool
    with open(file, 'r') as f:
        cont = 1
        for line in f:
            # print(line)
            if line[:4] != 'ATOM': continue
            if cont == 1:
                residue_name_length = len(f.readline()[17:20].strip())
            residue_name = line[17:20].strip()
            cont += 1
            if len(residue_name) == residue_name_length:
                continue
            else:
                return True
    return False

def read_druggability(pockets_info):
    score_dict = dict()
    with open(pockets_info, 'r') as f:
        pockets = f.read().strip().split('\n\n')
        for i, p in enumerate(pockets):
            i += 1
            score_dict[i] = float(p.split('\n')[2].split('\t')[2])
    return score_dict

def fpocket_filter(fpocket_out_folder, low_line=0.5):
    # 此函数用于过滤pocket，利用di_bind函数和分数
    pocket_folder = os.path.join(fpocket_out_folder, 'pockets')
    pockets_info_file = os.path.join(fpocket_out_folder, fpocket_out_folder.split('/')[-1][:-4]+'_info.txt')
    # pockets_file = [os.path.join(pocket_folder, file) for file in os.listdir(pocket_folder) if file[-3:]=='pdb']
    pockets_score = read_druggability(pockets_info_file)
    results = list()
    for i in pockets_score.keys():
        pocket_file_path = os.path.join(pocket_folder,f'pocket{i}_atm.pdb')
        if pockets_score[i] > low_line and is_dibind(pocket_file_path):
            results.append(i)
    return results

def rewrite_out_file(pdb_out_file:str, pockets:list):
    # 此函数用于将不在pockets的pocket删除，并将剩余的pocket重新编号
    with open(pdb_out_file, 'r') as f:
        line_list = f.read().strip().split('\n')
        # out_line = copy.deepcopy(line_list)
        for i, line in enumerate(line_list):
            # print(i)
            line_list[i] = line + '\n'
            line += '\n'
            if line[:6] == 'HETATM' and line[17:20] == 'STP':
                if int(line[22:26]) not in pockets:
                    line_list[i] = ''
                else:
                    line_list[i] = line[:22] + (' '*(4-len(str(pockets.index(int(line[22:26]))+1))) + str(pockets.index(int(line[22:26]))+1)) + line[26:]

    with open(pdb_out_file.replace('.pdb', '_new.pdb'), 'w') as f:
        f.writelines(line_list)
    # rewrite pml
    with open(pdb_out_file.replace('_out.pdb', '.pml'), 'r') as f:
        lines = f.readlines()
    with open(pdb_out_file.replace('_out.pdb', '_new.pml'), 'w') as f:
        pml_name = pdb_out_file.split('\\')[-1].replace('.pdb', '_new.pdb')
        lines[1] = f'load {pml_name}\n'
        f.writelines(lines)

# %% [markdown]
# # main函数

# %%
if __name__ == "__main__":
    # fpocket输出文件夹，例："E:\tmp\fpocket\6v5b_out"
    # fpocket_out_folder = r'E:/Research/SM_miRNA/Data/Dock/complex/pdb/1ibr_out'
    path = "E:/Research/SM_miRNA/Data/Dock/complex/pdb/"
    for fpocket_out_folder in [dir_tmp for dir_tmp in os.listdir(path) if not os.path.isfile(os.path.join(path, dir_tmp))]:
        print(fpocket_out_folder)
        fpocket_out_folder = os.path.join(path, fpocket_out_folder)
        print(fpocket_out_folder)

        pdb_out_file = os.path.join(fpocket_out_folder, fpocket_out_folder.split('/')[-1]+'.pdb')
        # pml_out_file = os.path.join(fpocket_out_folder, fpocket_out_folder.split('/')[-1].replace('_out.pdb', '.pml'))
        pockets = fpocket_filter(fpocket_out_folder, low_line=0.5)
        print(pockets)
        rewrite_out_file(pdb_out_file, pockets)
# Out:
# 1ibr_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/1ibr_out
# []
# 2li8_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/2li8_out
# []
# 3a6p_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/3a6p_out
# [5]
# 4w5o_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4w5o_out
# []
# 4w5q_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4w5q_out
# []
# 4w5r_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4w5r_out
# []
# 4w5t_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4w5t_out
# []
# 4z4c_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4z4c_out
# [1]
# 4z4d_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4z4d_out
# [7]
# 4z4e_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4z4e_out
# []
# 4z4f_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4z4f_out
# []
# 4z4g_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4z4g_out
# []
# 4z4h_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4z4h_out
# []
# 4z4i_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/4z4i_out
# []
# 5azm_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/5azm_out
# []
# 5udz_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/5udz_out
# []
# 5zak_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/5zak_out
# []
# 5zal_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/5zal_out
# [7]
# 5zam_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/5zam_out
# [5]
# 6cbd_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6cbd_out
# [44]
# 6lxd_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6lxd_out
# [90]
# 6lxe_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6lxe_out
# []
# 6mdz_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6mdz_out
# []
# 6mfn_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6mfn_out
# []
# 6mfr_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6mfr_out
# []
# 6n4o_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6n4o_out
# []
# 6nit_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6nit_out
# []
# 6v5b_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6v5b_out
# [19]
# 6v5c_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/6v5c_out
# []
# 7ki3_out
# E:/Research/SM_miRNA/Data/Dock/complex/pdb/7ki3_out
# []

# %%
read_druggability(fpocket_out_folder+'/6v5c_info.txt')
# Out:
# {1: 0.0,
#  2: 0.094,
#  3: 0.015,
#  4: 0.002,
#  5: 0.002,
#  6: 0.012,
#  7: 0.002,
#  8: 0.004,
#  9: 0.129,
#  10: 0.001,
#  11: 0.001,
#  12: 0.004,
#  13: 0.014,
#  14: 0.001,
#  15: 0.007,
#  16: 0.0,
#  17: 0.942,
#  18: 0.0,
#  19: 0.001,
#  20: 0.001,
#  21: 0.0,
#  22: 0.001,
#  23: 0.001,
#  24: 0.002,
#  25: 0.002,
#  26: 0.001,
#  27: 0.0,
#  28: 0.001,
#  29: 0.001,
#  30: 0.04,
#  31: 0.321,
#  32: 0.002,
#  33: 0.0,
#  34: 0.0,
#  35: 0.004,
#  36: 0.006,
#  37: 0.002,
#  38: 0.001,
#  39: 0.001,
#  40: 0.0,
#  41: 0.0,
#  42: 0.001,
#  43: 0.001,
#  44: 0.002,
#  45: 0.0,
#  46: 0.001,
#  47: 0.004,
#  48: 0.001,
#  49: 0.001,
#  50: 0.001,
#  51: 0.001,
#  52: 0.008,
#  53: 0.002,
#  54: 0.0,
#  55: 0.001,
#  56: 0.001,
#  57: 0.0,
#  58: 0.0,
#  59: 0.012,
#  60: 0.004,
#  61: 0.0,
#  62: 0.002,
#  63: 0.036,
#  64: 0.0,
#  65: 0.001,
#  66: 0.024,
#  67: 0.003,
#  68: 0.004,
#  69: 0.0,
#  70: 0.0,
#  71: 0.0,
#  72: 0.0,
#  73: 0.0,
#  74: 0.913,
#  75: 0.0,
#  76: 0.0,
#  77: 0.0,
#  78: 0.001,
#  79: 0.0,
#  80: 0.0,
#  81: 0.001,
#  82: 0.017,
#  83: 0.001,
#  84: 0.003,
#  85: 0.005,
#  86: 0.003,
#  87: 0.885,
#  88: 0.001,
#  89: 0.012,
#  90: 0.011,
#  91: 0.0,
#  92: 0.236,
#  93: 0.0,
#  94: 0.001,
#  95: 0.001,
#  96: 0.061,
#  97: 0.005,
#  98: 0.005,
#  99: 0.015,
#  100: 0.002,
#  101: 0.0,
#  102: 0.001,
#  103: 0.0,
#  104: 0.0,
#  105: 0.001,
#  106: 0.0,
#  107: 0.008,
#  108: 0.156,
#  109: 0.001,
#  110: 0.002,
#  111: 0.0,
#  112: 0.0,
#  113: 0.0,
#  114: 0.0,
#  115: 0.001,
#  116: 0.0,
#  117: 0.001,
#  118: 0.0,
#  119: 0.001,
#  120: 0.01,
#  121: 0.0,
#  122: 0.034,
#  123: 0.4,
#  124: 0.002,
#  125: 0.078,
#  126: 0.002,
#  127: 0.022,
#  128: 0.001,
#  129: 0.0,
#  130: 0.005,
#  131: 0.006,
#  132: 0.099,
#  133: 0.0,
#  134: 0.007,
#  135: 0.015,
#  136: 0.001,
#  137: 0.022,
#  138: 0.0}

# %% [markdown]
# # 输出文件

# %%
total_dict = dict()
for file in os.listdir('fpocket'):
    f = open(os.path.join('fpocket', file), 'r')
    pocket_atom = f.read()
    total_dict[file] = statistic_pocket_interaction(pocket_atom)

# %%
import pandas as pd
pd.DataFrame(total_dict)
# Out:
#    3a6p.pdb  4z4c.pdb  4z4d.pdb  5azl.pdb  5zam.pdb  6cbd.pdb  6lxd.pdb  \
# 3        85       140        57        64        86        36        88
# 1        16        63        48         5         4        29         2
#
#    6v5b.pdb
# 3        48
# 1         4
