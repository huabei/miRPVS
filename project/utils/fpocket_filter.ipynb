# %% [markdown]
# # 此文件用于筛选fpocket的输出结果

# %%
import os
import copy
from utils import statistic_pocket_interaction
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
FPOCKET_OUT_PATH = "E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures"

# %% [markdown]
# # 函数定义

# %%
def is_dibind_or_only_rna(file: str, or_only_rna=True) -> bool:
    """用于判断pocket文件中是否同时有蛋白质残基和RNA残基,pocket文件中包含一个口袋中表面的所有原子
    file: pocket文件路径
    return bool"""
    with open(file, 'r') as f:
        cont = 1
        for line in f:
            # print(line)
            if line[:4] != 'ATOM': continue
            if cont == 1: # 确定第一个残基的长度，RNA为1， 蛋白质为3
                residue_name_length = len(f.readline()[17:20].strip()) # 残基的位置在第17-20位
            residue_name = line[17:20].strip() # 获取当前行残基
            cont += 1
            # 如果残基的长度与第一个残基的长度相同，则跳过，不同则表明同时包含R和P的原子，返回True
            if len(residue_name) == residue_name_length:
                continue
            else:
                return True
    # 如果包含只有RNA的pocket，返回True
    if or_only_rna:
        if residue_name_length == 1:
            logging.info(f'只有RNA的pocket: {file}')
            return True
        else:
            return False
    # 如果循环结束，说明没有同时包含R和P的原子，返回False
    return False

def read_druggability(pockets_info_file: str):
    """根据fpocket输出的pocket信息文件，读取每个pocket的druggability分数
    pockets_info_file: fpocket输出的pocket信息文件"""
    
    score_dict = dict()
    with open(pockets_info_file, 'r') as f:
        pockets = f.read().strip().split('\n\n') # 每个pocket之间用两个换行符隔开
        for i, p in enumerate(pockets): # 遍历每个pocket，i为pocket的编号，p为pocket的信息
            i += 1
            score_dict[i] = float(p.split('\n')[2].split('\t')[2]) # pocket的druggability分数在第三行第三列
    return score_dict


def fpocket_filter(fpocket_out_folder: str, druggability_low_line: float=0.5) -> list:
    """此函数用来过滤fpocket输出的pocket，返回符合条件的pocket编号，利用di_bind函数和druggability分数
    fpocket_out_folder: fpocket针对一个pdb文件输出的文件夹
    druggability_low_line: druggability分数的下限
    return list of pocket number starting from 1
    """
    PDB_ID = os.path.split(fpocket_out_folder)[-1].split('_')[0]
    logging.info(f'正在处理{PDB_ID}')
    pocket_folder = os.path.join(fpocket_out_folder, 'pockets') # 输出文件夹中pockets文件夹的路径
    pockets_info_file = os.path.join(fpocket_out_folder, PDB_ID+'_info.txt')
    # pockets_file = [os.path.join(pocket_folder, file) for file in os.listdir(pocket_folder) if file[-3:]=='pdb']
    pockets_score = read_druggability(pockets_info_file) # 读取每个pocket的druggability分数
    
    # 结果返回符合条件的pocket编号列表
    results = list()
    for i in pockets_score.keys(): # i为pocket的编号
        pocket_file_path = os.path.join(pocket_folder,f'pocket{i}_atm.pdb') # 相应编号的pocket文件路径
        # 如果druggability分数大于下限并且同时包含蛋白质和RNA残基，则添加到结果列表中
        if pockets_score[i] > druggability_low_line and is_dibind_or_only_rna(pocket_file_path):
            results.append(i)
    return results


def rewrite_out_file(pdb_out_file:str, pockets:list):
    # 此函数用于将不在pockets的pocket删除，并将剩余的pocket重新编号
    with open(pdb_out_file, 'r') as f:
        line_list = f.read().strip().split('\n')
        # out_line = copy.deepcopy(line_list)
        for i, line in enumerate(line_list):
            # print(i)
            line_list[i] = line + '\n'
            line += '\n'
            if line[:6] == 'HETATM' and line[17:20] == 'STP':
                if int(line[22:26]) not in pockets:
                    line_list[i] = ''
                else:
                    # 更换pocket编号
                    line_list[i] = line[:22] + (' '*(4-len(str(pockets.index(int(line[22:26]))+1))) + str(pockets.index(int(line[22:26]))+1)) + line[26:]
    # 写入新的pdb文件
    new_pdb_out_file = pdb_out_file.replace('.pdb', '_new.pdb')
    with open(new_pdb_out_file, 'w') as f:
        f.writelines(line_list)
    # 写入新的pml文件
    with open(pdb_out_file.replace('_out.pdb', '.pml'), 'r') as f:
        lines = f.readlines()
    with open(pdb_out_file.replace('_out.pdb', '_new.pml'), 'w') as f:
        # 更换load的pdb文件为新的pdb文件
        lines[1] = f'load {new_pdb_out_file}\n'
        f.writelines(lines)

# %% [markdown]
# # main函数

# %%
if __name__ == "__main__":
    # fpocket输出文件夹，例："E:\tmp\fpocket\6v5b_out"
    # fpocket_out_folder = r'E:/Research/SM_miRNA/Data/Dock/complex/pdb/1ibr_out'
    path = FPOCKET_OUT_PATH
    all_pockets = dict()
    for fpocket_out_folder in [dir_tmp for dir_tmp in os.listdir(path) if not os.path.isfile(os.path.join(path, dir_tmp))]:
        logging.info(f'正在处理{fpocket_out_folder}')
        fpocket_out_folder = os.path.join(path, fpocket_out_folder)
        logging.info(f'fpocket_out_folder: {fpocket_out_folder}')
        pdb_id = os.path.split(fpocket_out_folder)[-1].split('_')[0]
        pdb_out_file = os.path.join(fpocket_out_folder, pdb_id+'_out.pdb')
        # pml_out_file = os.path.join(fpocket_out_folder, fpocket_out_folder.split('/')[-1].replace('_out.pdb', '.pml'))
        pockets = fpocket_filter(fpocket_out_folder, druggability_low_line=0)
        all_pockets[pdb_id] = pockets
        logging.info(f'pdb_id have pockets: {pockets}')
        rewrite_out_file(pdb_out_file, pockets)
        logging.info(f'处理完成{pdb_id}')
# Out:
# 2023-03-07 20:41:20,755 - INFO - 正在处理2LI8_out
# 2023-03-07 20:41:20,755 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\2LI8_out
# 2023-03-07 20:41:20,756 - INFO - 正在处理2LI8
# 2023-03-07 20:41:20,757 - INFO - pdb_id have pockets: [4]
# 2023-03-07 20:41:20,760 - INFO - 处理完成2LI8
# 2023-03-07 20:41:20,760 - INFO - 正在处理2N82_out
# 2023-03-07 20:41:20,760 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\2N82_out
# 2023-03-07 20:41:20,761 - INFO - 正在处理2N82
# 2023-03-07 20:41:20,765 - INFO - pdb_id have pockets: [2, 5, 8, 9, 10]
# 2023-03-07 20:41:20,770 - INFO - 处理完成2N82
# 2023-03-07 20:41:20,770 - INFO - 正在处理3A6P_out
# 2023-03-07 20:41:20,771 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\3A6P_out
# 2023-03-07 20:41:20,771 - INFO - 正在处理3A6P
# 2023-03-07 20:41:20,810 - INFO - pdb_id have pockets: [5, 14, 32, 34, 36, 40, 41, 50, 61, 73, 98, 115, 117, 119, 122, 154, 160, 161, 165, 169, 181, 184]
# 2023-03-07 20:41:20,840 - INFO - 处理完成3A6P
# 2023-03-07 20:41:20,841 - INFO - 正在处理4B8T_out
# 2023-03-07 20:41:20,841 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4B8T_out
# 2023-03-07 20:41:20,841 - INFO - 正在处理4B8T
# 2023-03-07 20:41:20,843 - INFO - pdb_id have pockets: [1]
# 2023-03-07 20:41:20,846 - INFO - 处理完成4B8T
# 2023-03-07 20:41:20,847 - INFO - 正在处理4F3T_out
# 2023-03-07 20:41:20,847 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4F3T_out
# 2023-03-07 20:41:20,848 - INFO - 正在处理4F3T
# 2023-03-07 20:41:20,862 - INFO - pdb_id have pockets: [7, 12, 20, 33, 44, 51]
# 2023-03-07 20:41:20,871 - INFO - 处理完成4F3T
# 2023-03-07 20:41:20,871 - INFO - 正在处理4KRE_out
# 2023-03-07 20:41:20,872 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4KRE_out
# 2023-03-07 20:41:20,872 - INFO - 正在处理4KRE
# 2023-03-07 20:41:20,883 - INFO - pdb_id have pockets: [23, 42, 51, 53]
# 2023-03-07 20:41:20,891 - INFO - 处理完成4KRE
# 2023-03-07 20:41:20,892 - INFO - 正在处理4KRF_out
# 2023-03-07 20:41:20,892 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4KRF_out
# 2023-03-07 20:41:20,892 - INFO - 正在处理4KRF
# 2023-03-07 20:41:20,900 - INFO - pdb_id have pockets: [9, 11, 25, 29, 39]
# 2023-03-07 20:41:20,909 - INFO - 处理完成4KRF
# 2023-03-07 20:41:20,909 - INFO - 正在处理4W5N_out
# 2023-03-07 20:41:20,909 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4W5N_out
# 2023-03-07 20:41:20,910 - INFO - 正在处理4W5N
# 2023-03-07 20:41:20,922 - INFO - pdb_id have pockets: [7, 13, 31, 32, 40, 43, 57, 59, 60, 61]
# 2023-03-07 20:41:20,932 - INFO - 处理完成4W5N
# 2023-03-07 20:41:20,932 - INFO - 正在处理4W5O_out
# 2023-03-07 20:41:20,932 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4W5O_out
# 2023-03-07 20:41:20,933 - INFO - 正在处理4W5O
# 2023-03-07 20:41:20,942 - INFO - pdb_id have pockets: [4, 10, 20, 25, 26, 34, 35, 39, 40, 42, 44, 45]
# 2023-03-07 20:41:20,952 - INFO - 处理完成4W5O
# 2023-03-07 20:41:20,953 - INFO - 正在处理4W5Q_out
# 2023-03-07 20:41:20,953 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4W5Q_out
# 2023-03-07 20:41:20,953 - INFO - 正在处理4W5Q
# 2023-03-07 20:41:20,962 - INFO - pdb_id have pockets: [5, 10, 15, 16, 21, 22, 41, 47]
# 2023-03-07 20:41:20,972 - INFO - 处理完成4W5Q
# 2023-03-07 20:41:20,972 - INFO - 正在处理4W5R_out
# 2023-03-07 20:41:20,973 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4W5R_out
# 2023-03-07 20:41:20,973 - INFO - 正在处理4W5R
# 2023-03-07 20:41:20,981 - INFO - pdb_id have pockets: [9, 16, 33, 35, 39, 45, 47, 56, 57]
# 2023-03-07 20:41:20,990 - INFO - 处理完成4W5R
# 2023-03-07 20:41:20,991 - INFO - 正在处理4W5T_out
# 2023-03-07 20:41:20,991 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4W5T_out
# 2023-03-07 20:41:20,992 - INFO - 正在处理4W5T
# 2023-03-07 20:41:21,002 - INFO - pdb_id have pockets: [6, 9, 12, 24, 25, 28, 31, 35, 45, 47, 52]
# 2023-03-07 20:41:21,011 - INFO - 处理完成4W5T
# 2023-03-07 20:41:21,012 - INFO - 正在处理4Z4C_out
# 2023-03-07 20:41:21,012 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4Z4C_out
# 2023-03-07 20:41:21,012 - INFO - 正在处理4Z4C
# 2023-03-07 20:41:21,021 - INFO - pdb_id have pockets: [1, 6, 17, 21, 37, 38, 39, 40, 41, 44]
# 2023-03-07 20:41:21,031 - INFO - 处理完成4Z4C
# 2023-03-07 20:41:21,032 - INFO - 正在处理4Z4D_out
# 2023-03-07 20:41:21,032 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4Z4D_out
# 2023-03-07 20:41:21,032 - INFO - 正在处理4Z4D
# 2023-03-07 20:41:21,042 - INFO - pdb_id have pockets: [6, 7, 9, 20, 24, 30, 31, 42, 43, 44]
# 2023-03-07 20:41:21,052 - INFO - 处理完成4Z4D
# 2023-03-07 20:41:21,053 - INFO - 正在处理4Z4E_out
# 2023-03-07 20:41:21,053 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4Z4E_out
# 2023-03-07 20:41:21,054 - INFO - 正在处理4Z4E
# 2023-03-07 20:41:21,064 - INFO - pdb_id have pockets: [6, 10, 14, 23, 24, 25, 28, 39, 42, 47, 50]
# 2023-03-07 20:41:21,073 - INFO - 处理完成4Z4E
# 2023-03-07 20:41:21,074 - INFO - 正在处理4Z4F_out
# 2023-03-07 20:41:21,074 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4Z4F_out
# 2023-03-07 20:41:21,074 - INFO - 正在处理4Z4F
# 2023-03-07 20:41:21,084 - INFO - pdb_id have pockets: [9, 11, 37, 43, 48, 50, 53]
# 2023-03-07 20:41:21,095 - INFO - 处理完成4Z4F
# 2023-03-07 20:41:21,095 - INFO - 正在处理4Z4G_out
# 2023-03-07 20:41:21,096 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4Z4G_out
# 2023-03-07 20:41:21,096 - INFO - 正在处理4Z4G
# 2023-03-07 20:41:21,105 - INFO - pdb_id have pockets: [1, 8, 15, 19, 35, 40, 50, 51, 53, 55]
# 2023-03-07 20:41:21,117 - INFO - 处理完成4Z4G
# 2023-03-07 20:41:21,117 - INFO - 正在处理4Z4H_out
# 2023-03-07 20:41:21,118 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4Z4H_out
# 2023-03-07 20:41:21,118 - INFO - 正在处理4Z4H
# 2023-03-07 20:41:21,128 - INFO - pdb_id have pockets: [7, 15, 27, 34, 41, 45, 47, 49]
# 2023-03-07 20:41:21,137 - INFO - 处理完成4Z4H
# 2023-03-07 20:41:21,138 - INFO - 正在处理4Z4I_out
# 2023-03-07 20:41:21,138 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\4Z4I_out
# 2023-03-07 20:41:21,138 - INFO - 正在处理4Z4I
# 2023-03-07 20:41:21,148 - INFO - pdb_id have pockets: [5, 18, 19, 25, 45, 47, 48]
# 2023-03-07 20:41:21,158 - INFO - 处理完成4Z4I
# 2023-03-07 20:41:21,158 - INFO - 正在处理5UDZ_out
# 2023-03-07 20:41:21,159 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\5UDZ_out
# 2023-03-07 20:41:21,159 - INFO - 正在处理5UDZ
# 2023-03-07 20:41:21,163 - INFO - pdb_id have pockets: [1, 2, 4, 5, 6, 22]
# 2023-03-07 20:41:21,168 - INFO - 处理完成5UDZ
# 2023-03-07 20:41:21,168 - INFO - 正在处理5UZZ_out
# 2023-03-07 20:41:21,169 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\5UZZ_out
# 2023-03-07 20:41:21,169 - INFO - 正在处理5UZZ
# 2023-03-07 20:41:21,172 - INFO - 只有RNA的pocket: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\5UZZ_out\pockets\pocket5_atm.pdb
# 2023-03-07 20:41:21,172 - INFO - pdb_id have pockets: [1, 4, 5]
# 2023-03-07 20:41:21,174 - INFO - 处理完成5UZZ
# 2023-03-07 20:41:21,175 - INFO - 正在处理5ZAL_out
# 2023-03-07 20:41:21,175 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\5ZAL_out
# 2023-03-07 20:41:21,175 - INFO - 正在处理5ZAL
# 2023-03-07 20:41:21,198 - INFO - pdb_id have pockets: [7, 22]
# 2023-03-07 20:41:21,216 - INFO - 处理完成5ZAL
# 2023-03-07 20:41:21,216 - INFO - 正在处理5ZAM_out
# 2023-03-07 20:41:21,216 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\5ZAM_out
# 2023-03-07 20:41:21,217 - INFO - 正在处理5ZAM
# 2023-03-07 20:41:21,243 - INFO - pdb_id have pockets: [5, 11, 36]
# 2023-03-07 20:41:21,260 - INFO - 处理完成5ZAM
# 2023-03-07 20:41:21,261 - INFO - 正在处理6CBD_out
# 2023-03-07 20:41:21,261 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6CBD_out
# 2023-03-07 20:41:21,261 - INFO - 正在处理6CBD
# 2023-03-07 20:41:21,274 - INFO - pdb_id have pockets: [1, 4, 17, 27, 31, 32, 33, 39, 43, 44]
# 2023-03-07 20:41:21,284 - INFO - 处理完成6CBD
# 2023-03-07 20:41:21,285 - INFO - 正在处理6DCL_out
# 2023-03-07 20:41:21,285 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6DCL_out
# 2023-03-07 20:41:21,285 - INFO - 正在处理6DCL
# 2023-03-07 20:41:21,291 - INFO - pdb_id have pockets: [1, 2, 3, 4, 6, 19, 20, 21]
# 2023-03-07 20:41:21,296 - INFO - 处理完成6DCL
# 2023-03-07 20:41:21,297 - INFO - 正在处理6LXD_out
# 2023-03-07 20:41:21,297 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6LXD_out
# 2023-03-07 20:41:21,297 - INFO - 正在处理6LXD
# 2023-03-07 20:41:21,316 - INFO - pdb_id have pockets: [18, 23, 25, 45, 58, 67, 74, 81, 88, 90, 92, 94]
# 2023-03-07 20:41:21,332 - INFO - 处理完成6LXD
# 2023-03-07 20:41:21,333 - INFO - 正在处理6MDZ_out
# 2023-03-07 20:41:21,333 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6MDZ_out
# 2023-03-07 20:41:21,333 - INFO - 正在处理6MDZ
# 2023-03-07 20:41:21,350 - INFO - pdb_id have pockets: [15, 18, 21, 51, 52, 55, 61, 79, 85, 88, 91, 94, 96, 102]
# 2023-03-07 20:41:21,369 - INFO - 处理完成6MDZ
# 2023-03-07 20:41:21,370 - INFO - 正在处理6MFN_out
# 2023-03-07 20:41:21,370 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6MFN_out
# 2023-03-07 20:41:21,371 - INFO - 正在处理6MFN
# 2023-03-07 20:41:21,381 - INFO - pdb_id have pockets: [9, 21, 47]
# 2023-03-07 20:41:21,390 - INFO - 处理完成6MFN
# 2023-03-07 20:41:21,390 - INFO - 正在处理6MFR_out
# 2023-03-07 20:41:21,390 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6MFR_out
# 2023-03-07 20:41:21,391 - INFO - 正在处理6MFR
# 2023-03-07 20:41:21,411 - INFO - pdb_id have pockets: [16, 18, 36, 47, 59, 94, 95, 96, 99, 100, 102, 105, 109, 113, 115]
# 2023-03-07 20:41:21,431 - INFO - 处理完成6MFR
# 2023-03-07 20:41:21,432 - INFO - 正在处理6N4O_out
# 2023-03-07 20:41:21,432 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6N4O_out
# 2023-03-07 20:41:21,433 - INFO - 正在处理6N4O
# 2023-03-07 20:41:21,447 - INFO - pdb_id have pockets: [2, 3, 7, 8, 13, 14, 16, 20, 21, 33, 36, 43, 54, 56]
# 2023-03-07 20:41:21,458 - INFO - 处理完成6N4O
# 2023-03-07 20:41:21,459 - INFO - 正在处理6NIT_out
# 2023-03-07 20:41:21,460 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6NIT_out
# 2023-03-07 20:41:21,460 - INFO - 正在处理6NIT
# 2023-03-07 20:41:21,480 - INFO - pdb_id have pockets: [9, 22, 47, 52, 59, 60, 65, 77, 91, 98, 99, 103, 110, 111]
# 2023-03-07 20:41:21,499 - INFO - 处理完成6NIT
# 2023-03-07 20:41:21,499 - INFO - 正在处理6UV2_out
# 2023-03-07 20:41:21,500 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6UV2_out
# 2023-03-07 20:41:21,500 - INFO - 正在处理6UV2
# 2023-03-07 20:41:21,506 - INFO - pdb_id have pockets: [8, 11, 26]
# 2023-03-07 20:41:21,511 - INFO - 处理完成6UV2
# 2023-03-07 20:41:21,512 - INFO - 正在处理6UV3_out
# 2023-03-07 20:41:21,512 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6UV3_out
# 2023-03-07 20:41:21,513 - INFO - 正在处理6UV3
# 2023-03-07 20:41:21,518 - INFO - pdb_id have pockets: [18, 20]
# 2023-03-07 20:41:21,524 - INFO - 处理完成6UV3
# 2023-03-07 20:41:21,524 - INFO - 正在处理6UV4_out
# 2023-03-07 20:41:21,524 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6UV4_out
# 2023-03-07 20:41:21,525 - INFO - 正在处理6UV4
# 2023-03-07 20:41:21,530 - INFO - pdb_id have pockets: [9]
# 2023-03-07 20:41:21,535 - INFO - 处理完成6UV4
# 2023-03-07 20:41:21,535 - INFO - 正在处理6V5B_out
# 2023-03-07 20:41:21,536 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6V5B_out
# 2023-03-07 20:41:21,536 - INFO - 正在处理6V5B
# 2023-03-07 20:41:21,559 - INFO - pdb_id have pockets: [7, 9, 11, 14, 18, 19, 20, 37, 40, 42, 62, 69, 70, 71, 75, 94, 95, 99, 102, 106, 108, 109, 112, 113, 114]
# 2023-03-07 20:41:21,580 - INFO - 处理完成6V5B
# 2023-03-07 20:41:21,580 - INFO - 正在处理6V5C_out
# 2023-03-07 20:41:21,580 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\6V5C_out
# 2023-03-07 20:41:21,581 - INFO - 正在处理6V5C
# 2023-03-07 20:41:21,609 - INFO - pdb_id have pockets: [12, 13, 26, 28, 29, 38, 43, 51, 65, 99, 109, 115, 119, 127, 128, 131, 136]
# 2023-03-07 20:41:21,629 - INFO - 处理完成6V5C
# 2023-03-07 20:41:21,630 - INFO - 正在处理7KI3_out
# 2023-03-07 20:41:21,630 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\7KI3_out
# 2023-03-07 20:41:21,631 - INFO - 正在处理7KI3
# 2023-03-07 20:41:21,651 - INFO - pdb_id have pockets: [2, 5, 10, 21, 23, 24, 41, 63, 69, 74, 85, 86, 88, 92, 96, 97, 99, 102, 103]
# 2023-03-07 20:41:21,671 - INFO - 处理完成7KI3
# 2023-03-07 20:41:21,671 - INFO - 正在处理test_out
# 2023-03-07 20:41:21,671 - INFO - fpocket_out_folder: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\test_out
# 2023-03-07 20:41:21,672 - INFO - 正在处理test
# 2023-03-07 20:41:21,673 - INFO - 只有RNA的pocket: E:\Research\SM_miRNA\Data\complex_structure\complex-pdb-structures\test_out\pockets\pocket1_atm.pdb
# 2023-03-07 20:41:21,674 - INFO - pdb_id have pockets: [1, 4]
# 2023-03-07 20:41:21,677 - INFO - 处理完成test

# %%
# read_druggability(fpocket_out_folder+'/6v5c_info.txt')
pdb_id = os.path.split(fpocket_out_folder)[-1].split('_')[0]

# %% [markdown]
# # 输出文件

# %%
total_dict = dict()
for file in os.listdir('fpocket'):
    f = open(os.path.join('fpocket', file), 'r')
    pocket_atom = f.read()
    total_dict[file] = statistic_pocket_interaction(pocket_atom)

# %%
import pandas as pd
pd.DataFrame(total_dict)
# Out:
#    3a6p_pocket5_atm.pdb  4z4c_pocket1_atm.pdb  4z4d_pocket7_atm.pdb  \
# 3                    85                   140                    57
# 1                    16                    63                    48
#
#    5zal_pocket7_atm.pdb  5zam_pocket5_atm.pdb  6cbd_pocket44_atm.pdb  \
# 3                    64                    86                     36
# 1                     5                     4                     29
#
#    6dcl_pocket2_atm.pdb  6lxd_pocket90_atm.pdb  6v5b_pocket19_atm.pdb
# 3                    60                     88                     48
# 1                     2                      2                      4
